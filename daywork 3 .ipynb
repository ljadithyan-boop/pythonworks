# %%
feedback_message=" Hello Team, the service was Excellent! "
print(feedback_message)
print(feedback_message.strip())
print(feedback_message.upper())
print(feedback_message.lower())
print(len(feedback_message))
x=len(feedback_message)
if "service" in feedback_message:
    print("this message found")
if "bad" not in feedback_message:
    print("this message not found")
y=("this messege found")
z=("this message not found")
print(feedback_message[1:2])
print(feedback_message[-2:-1])
print(feedback_message[17:24])
print(f"the corrected message is{feedback_message}length of the string is{x},the substring check result is {y,z}")
# Out:
#  Hello Team, the service was Excellent!
# Hello Team, the service was Excellent!
#  HELLO TEAM, THE SERVICE WAS EXCELLENT!
#  hello team, the service was excellent!
# 40
# this message found
# this message not found
# H
# !
# service
# the corrected message is Hello Team, the service was Excellent! length of the string is40,the substring check result is ('this messege found', 'this message not found')
