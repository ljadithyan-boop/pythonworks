# %%
product_name="mobile"
price=50000
quantity=10
discount_percent=10
x=product_name
y=price
z=quantity
a=discount_percent
print(x,y,z,a)
w=float(y)
b=int(z)
print(w,b)
total_amount=y*z
discount_amount=y*discount_percent/100
final_amount=total_amount-discount_amount
tax=service_charge=5
print(total_amount,discount_amount,final_amount,tax)



print(type(final_amount))
# Out:
# mobile 50000 10 10
# 50000.0 10
# 500000 5000.0 495000.0 5
# <class 'float'>
