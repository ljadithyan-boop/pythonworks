# %%
stud_name="rahul"
stud_age=21
is_enrolled=True
x=stud_name
y=stud_age
z=is_enrolled
print(type(z))
print(type(x))
print(type(y))
book_price="two hundred fifty"
book_quantity="twenty five"
x=book_price
y=book_quantity
print(x,y)
book_price="400"
book_quantity="25"
x=book_price
y=book_quantity
z=int(x)
a=int(y)
print(z,a)
book_price=400
book_quantity=25
x=book_price
y=book_quantity
total_cost=x*y
print(total_cost)
stud_name="rahul"
stud_age=21
stud_age=34
print(stud_age)
print(stud_name)
print(total_cost)



print(stud_age)
# Out:
# <class 'bool'>
# <class 'str'>
# <class 'int'>
# two hundred fifty twenty five
# 400 25
# 10000
# 34
# rahul
# 10000
# 34
