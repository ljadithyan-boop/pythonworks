# %%
student_name ="rahul"
exam_score =75
attendance_percentage=80
bonus_marks=2
a=student_name
b=exam_score
c=attendance_percentage
d=bonus_marks
total_score=b+d
final_score=b*d
update_score=0
score=75
update_score+=score
print(final_score>=75)
print(attendance_percentage>=80)
eligibility=final_score<50
print(final_score>=75 and eligibility>=80)
print(a,final_score,c,eligibility)
# Out:
# True
# True
# False
# rahul 150 80 False
