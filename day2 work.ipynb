# %%
unit_price=25
quantity_sold=80
sales_target=25000
x=unit_price
y=quantity_sold
z=sales_target
total_sales=x*y
c=total_sales
new_sales=60000
add_sales=0
add_sales+=new_sales
print(c>=z)
print(z==25000 and y>0)
print(x,y,z,c,a)
# Out:
# False
# True
# 25 80 25000 2000 60000
