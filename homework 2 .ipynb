# %%
student_name ="rahul"
exam_score =75
attendance_percentage=80
bonus_marks=2
a=student_name
b=exam_score
c=attendance_percentage
d=bonus_marks
total_score=b+d
final_score=b*d
d=final_score
update_score=0
score=75
update_score+=score
print(final_score>=75)
print(attendance_percentage>=80)
eligibility=(final_score>=75 and attendance_percentage>=80)
e=eligibility
print("the student_name is ",a)
print("the final_score is ",d)
print("the attendance_percentage is ",c)
print("the eligibility is",e)
# Out:
# True
# True
# the student_name is  rahul
# the final_score is  150
# the attendance_percentage is  80
# the eligibility is True
