# %%
user_bio="""Hi, I am Anjali
I love Python programming
Improving my programming skills is my goal"""
print(user_bio)
print(user_bio.strip())
print(len(user_bio))
print(user_bio.split())
for character  in user_bio:
    print(character)
if "python" in user_bio:
    print("this message is found")
if "java" not in user_bio:
    print("this message not found")
x=("this message is found")
y=("this message not found")
print(user_bio.replace("Anjali","student"))
print(user_bio.split("."))
print(user_bio + "i love programming")
name="anjali"
rollno=25
print('my name is {}','my roll no is {}.'.format(name , rollno)) 
print(f"the corrected message is {user_bio}", "the substring check result is {x,y}") 
print(user_bio+"i love progrmming \n ")
print("\"its a very nice language used for coding\"")
# Out:
# Hi, I am Anjali
# I love Python programming
# Improving my programming skills is my goal
# Hi, I am Anjali
# I love Python programming
# Improving my programming skills is my goal
# 84
# ['Hi,', 'I', 'am', 'Anjali', 'I', 'love', 'Python', 'programming', 'Improving', 'my', 'programming', 'skills', 'is', 'my', 'goal']
# H
# i
# ,
#
# I
#
# a
# m
#
# A
# n
# j
# a
# l
# i
#
#
# I
#
# l
# o
# v
# e
#
# P
# y
# t
# h
# o
# n
#
# p
# r
# o
# g
# r
# a
# m
# m
# i
# n
# g
#
#
# I
# m
# p
# r
# o
# v
# i
# n
# g
#
# m
# y
#
# p
# r
# o
# g
# r
# a
# m
# m
# i
# n
# g
#
# s
# k
# i
# l
# l
# s
#
# i
# s
#
# m
# y
#
# g
# o
# a
# l
# this message not found
# Hi, I am student
# I love Python programming
# Improving my programming skills is my goal
# ['Hi, I am Anjali\nI love Python programming\nImproving my programming skills is my goal']
# Hi, I am Anjali
# I love Python programming
# Improving my programming skills is my goali love programming
# my name is {} my roll no is anjali.
# ...
